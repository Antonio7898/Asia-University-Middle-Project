# %% [markdown]
# # Vaccine

# %%
import os
ClassType= 'vaccine'
Inputfile = 'pubmed-vaccine-set_10000.txt'

# %%
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    Lines = file_input.readlines()
    #print (Lines)
cnt = 0
LineIndex = 0
PMID_LineIndex = []
for OneLine in Lines:
    LineIndex = LineIndex + 1
    if (OneLine.startswith('PMID-')):
        cnt = cnt +1
        PMID_LineIndex.append(LineIndex)
PMID_LineIndex.append(LineIndex)
#print(cnt)    
#print(PMID_LineIndex)


PUMID_List = []
TI_List = []
AB_List = []
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    for i in range(0,cnt):
        StartLineIndex = PMID_LineIndex[i]
        EndLineIndex = PMID_LineIndex[i+1]
        OnePUMID = []
        for j in range(StartLineIndex,EndLineIndex):
            OneLine = file_input.readline()
            #OneLine = OneLine.strip()
            #print(OneLine)
            OnePUMID.append(OneLine)
        #print(len(OnePUMID))
        #print(OnePUMID)
        #for k in range(len(OnePUMID)):
        OnePubMed_LineCnt = len(OnePUMID)
        #print(OnePubMed_LineCnt)
        OneTI_Info = []
        OneAB_Info = []
        k=0
        while (k < OnePubMed_LineCnt):
            #print(str(k)+'=>'+OnePUMID[k])
            if (OnePUMID[k].startswith('PMID-')):
                OnePUMID_Info = OnePUMID[k].split('- ')
                #print(str(k)+' PMID:'+OnePUMID_Info[1])
            #if (OnePUMID[k].startswith('TI  -')): # 
            if (OnePUMID[k].startswith('TI  -') or OnePUMID[k].startswith('Ti  -')):
                OneTI_Info = OnePUMID[k].split('- ')
                OneTI_Info[1] = OneTI_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneTI_Info[1] = OneTI_Info[1]+' '+Temp[1].strip()
                    k += 1
                #print(str(k)+' TI:'+OneTI_Info[1])
            if (OnePUMID[k].startswith('AB  -')):
                OneAB_Info = OnePUMID[k].split('- ')
                OneAB_Info[1] = OneAB_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneAB_Info[1] = OneAB_Info[1]+' '+Temp[1].strip()
                    k += 1
               # print(str(k)+' AB:'+OneAB_Info[1])
            k += 1
        PUMID_List.append(OnePUMID_Info[1].strip())
        TI_List.append(OneTI_Info[1].strip())
        if (len(OneAB_Info) == 2):
            AB_List.append(OneAB_Info[1].strip())
        else:
            AB_List.append('')
            print(OnePUMID_Info[1].strip()+"No Abstract")
        #AB_List.append(OneAB_Info[1].strip())
        
       
#PUMID_List
#TI_List
AB_List
# Out:
# 28125375No Abstract
# 31015742No Abstract
# 30542842No Abstract
# 22883365No Abstract
# 19829081No Abstract
# 31339795No Abstract
# 7795687No Abstract
# 26250703No Abstract
# 10797799No Abstract
# 22051135No Abstract
# 28806156No Abstract
# 21358267No Abstract
# 8338458No Abstract
# 30759470No Abstract
# 14089614No Abstract
# 23896587No Abstract
# 31280946No Abstract
# 17066597No Abstract
# 25483707No Abstract
# 1344874No Abstract
# 14221176No Abstract
# 25483551No Abstract
# 24018552No Abstract
# 13113285No Abstract
# 13560961No Abstract
# 14979004No Abstract
# 2420263No Abstract
# 23817318No Abstract
# 13368688No Abstract
# 4907913No Abstract
# 24553362No Abstract
# 13540284No Abstract
# 14275813No Abstract
# 14195986No Abstract
# 13214504No Abstract
# 14110035No Abstract
# 14295816No Abstract
# 14037810No Abstract
# 26087522No Abstract
# 13622573No Abstract
# 13076258No Abstract
# 14165824No Abstract
# 17520753No Abstract
# 13799657No Abstract
# 14874600No Abstract
# ...

# %%
PubMed_Data = [[PUMID_List[i],TI_List[i],AB_List[i]] for i in range(cnt)]
import pandas as pd
Pub_Vacc = pd.DataFrame(PubMed_Data , columns = ['PUMID' , 'TI','AB'])
Pub_Vacc['Type'] = ClassType
Pub_Vacc.head()
# Out:
#       PUMID                                                 TI  \
# 0  30676241  Addressing HPV vaccine myths: practical inform...
# 1  29217317           Recent Advances in Vaccine Technologies.
# 2  28774498  Vaccine Hesitancy: Where We Are and Where We A...
# 3  25483505  What are the factors that contribute to parent...
# 4  27810314        Vaccine hesitancy and healthcare providers.
#
#                                                   AB     Type
# 0  Human papillomavirus (HPV) vaccine uptake cons...  vaccine
# 1  This brief review discusses some recent advanc...  vaccine
# 2  PURPOSE: Vaccines represent one of the most im...  vaccine
# 3  Parental refusal or delay of childhood vaccine...  vaccine
# 4  While most people vaccinate according to the r...  vaccine

# %%
Pub_Vacc['Content'] = Pub_Vacc['TI'] + Pub_Vacc['AB']
Pub_Vacc
# Out:
#          PUMID                                                 TI  \
# 0     30676241  Addressing HPV vaccine myths: practical inform...
# 1     29217317           Recent Advances in Vaccine Technologies.
# 2     28774498  Vaccine Hesitancy: Where We Are and Where We A...
# 3     25483505  What are the factors that contribute to parent...
# 4     27810314        Vaccine hesitancy and healthcare providers.
# ...        ...                                                ...
# 9995   7777340  Bait formulation and distribution for oral rab...
# 9996  30201034  Acceptability of the dengue vaccination among ...
# 9997  10105760  Screening costs in a hepatitis B vaccine program.
# 9998   9098653  Japanese encephalitis vaccine in travellers. I...
# 9999  29525571  Vaccination coverage among children and adoles...
#
#                                                      AB     Type  \
# 0     Human papillomavirus (HPV) vaccine uptake cons...  vaccine
# ...

# %%
Pub_Vacc = Pub_Vacc.reindex(columns = ['PUMID','TI','AB','Content','Type'])
Pub_Vacc
# Out:
#          PUMID                                                 TI  \
# 0     30676241  Addressing HPV vaccine myths: practical inform...
# 1     29217317           Recent Advances in Vaccine Technologies.
# 2     28774498  Vaccine Hesitancy: Where We Are and Where We A...
# 3     25483505  What are the factors that contribute to parent...
# 4     27810314        Vaccine hesitancy and healthcare providers.
# ...        ...                                                ...
# 9995   7777340  Bait formulation and distribution for oral rab...
# 9996  30201034  Acceptability of the dengue vaccination among ...
# 9997  10105760  Screening costs in a hepatitis B vaccine program.
# 9998   9098653  Japanese encephalitis vaccine in travellers. I...
# 9999  29525571  Vaccination coverage among children and adoles...
#
#                                                      AB  \
# 0     Human papillomavirus (HPV) vaccine uptake cons...
# 1     This brief review discusses some recent advanc...
# ...

# %%
vacc_1 = Pub_Vacc[['Content' , 'Type']]

# %%
vacc_1
a1 = vacc_1.head(2000)

# %%
a1
# Out:
#                                                Content     Type
# 0    Addressing HPV vaccine myths: practical inform...  vaccine
# 1    Recent Advances in Vaccine Technologies.This b...  vaccine
# 2    Vaccine Hesitancy: Where We Are and Where We A...  vaccine
# 3    What are the factors that contribute to parent...  vaccine
# 4    Vaccine hesitancy and healthcare providers.Whi...  vaccine
# ..                                                 ...      ...
# 495  [On the problem of neurologic complications fo...  vaccine
# 496  [APROPOS OF COMBINED VACCINATIONS IN GENERAL A...  vaccine
# 497  Newcastle disease: effects of vaccines and vac...  vaccine
# 498  [ON VACCINAL PROPHYLAXIS IN RELATION TO AN EPI...  vaccine
# 499  [APROPOS OF VACCINAL COMPLICATIONS AFTER ORAL ...  vaccine
#
# [500 rows x 2 columns]

# %% [markdown]
# # covid-19

# %%
ClassType= 'COVID-19'
Inputfile = 'pubmed-COVID-19-set_10000.txt'

# %%
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    Lines = file_input.readlines()
    #print (Lines)
cnt = 0
LineIndex = 0
PMID_LineIndex = []
for OneLine in Lines:
    LineIndex = LineIndex + 1
    if (OneLine.startswith('PMID-')):
        cnt = cnt +1
        PMID_LineIndex.append(LineIndex)
PMID_LineIndex.append(LineIndex)
#print(cnt)    
#print(PMID_LineIndex)


PUMID_List = []
TI_List = []
AB_List = []
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    for i in range(0,cnt):
        StartLineIndex = PMID_LineIndex[i]
        EndLineIndex = PMID_LineIndex[i+1]
        OnePUMID = []
        for j in range(StartLineIndex,EndLineIndex):
            OneLine = file_input.readline()
            #OneLine = OneLine.strip()
            #print(OneLine)
            OnePUMID.append(OneLine)
        #print(len(OnePUMID))
        #print(OnePUMID)
        #for k in range(len(OnePUMID)):
        OnePubMed_LineCnt = len(OnePUMID)
        #print(OnePubMed_LineCnt)
        OneTI_Info = []
        OneAB_Info = []
        k=0
        while (k < OnePubMed_LineCnt):
            #print(str(k)+'=>'+OnePUMID[k])
            if (OnePUMID[k].startswith('PMID-')):
                OnePUMID_Info = OnePUMID[k].split('- ')
                #print(str(k)+' PMID:'+OnePUMID_Info[1])
            #if (OnePUMID[k].startswith('TI  -')): # 
            if (OnePUMID[k].startswith('TI  -') or OnePUMID[k].startswith('Ti  -')):
                OneTI_Info = OnePUMID[k].split('- ')
                OneTI_Info[1] = OneTI_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneTI_Info[1] = OneTI_Info[1]+' '+Temp[1].strip()
                    k += 1
                #print(str(k)+' TI:'+OneTI_Info[1])
            if (OnePUMID[k].startswith('AB  -')):
                OneAB_Info = OnePUMID[k].split('- ')
                OneAB_Info[1] = OneAB_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneAB_Info[1] = OneAB_Info[1]+' '+Temp[1].strip()
                    k += 1
               # print(str(k)+' AB:'+OneAB_Info[1])
            k += 1
        PUMID_List.append(OnePUMID_Info[1].strip())
        TI_List.append(OneTI_Info[1].strip())
        if (len(OneAB_Info) == 2):
            AB_List.append(OneAB_Info[1].strip())
        else:
            AB_List.append('')
            print(OnePUMID_Info[1].strip()+"No Abstract")
        #AB_List.append(OneAB_Info[1].strip())
        
       
#PUMID_List
#TI_List
# Out:
# 33139420No Abstract
# 33007240No Abstract
# 32916249No Abstract
# 33231027No Abstract
# 33215941No Abstract
# 32949173No Abstract
# 32385842No Abstract
# 32687598No Abstract
# 33469769No Abstract
# 32610807No Abstract
# 32541689No Abstract
# 34550303No Abstract
# 33399188No Abstract
# 33560305No Abstract
# 33880176No Abstract
# 32610818No Abstract
# 34244089No Abstract
# 33838847No Abstract
# 33663969No Abstract
# 34561140No Abstract
# 34340969No Abstract
# 33845717No Abstract
# 34019949No Abstract
# 33278609No Abstract
# 33934534No Abstract
# 33618823No Abstract
# 33405498No Abstract
# 33913561No Abstract
# 33838846No Abstract
# 33757504No Abstract
# 34322607No Abstract
# 34503968No Abstract
# 33725359No Abstract
# 32979317No Abstract
# 33516284No Abstract
# 33734625No Abstract
# 33403877No Abstract
# 33792892No Abstract
# 33609444No Abstract
# 33504396No Abstract
# 34477051No Abstract
# 33518226No Abstract
# 33276834No Abstract
# 33349351No Abstract
# 32940647No Abstract
# ...

# %%
PubMed_Data = [[PUMID_List[i],TI_List[i],AB_List[i]] for i in range(cnt)]
Pub_CV = pd.DataFrame(PubMed_Data , columns = ['PUMID' , 'TI','AB'])
Pub_CV['Type'] = ClassType

# %%
Pub_CV.head()
# Out:
#       PUMID                                                 TI  \
# 0  33172592  Update in COVID-19 in the intensive care unit ...
# 1  33187528  Rapid SARS-CoV-2 antigen detection assay in co...
# 2  33139420  Evaluation of the Panbio COVID-19 Rapid Antige...
# 3  32761898  A systematic review and meta-analysis of child...
# 4  33410425  COVID-19: Advances in diagnostic tools, treatm...
#
#                                                   AB      Type
# 0  The 2020 International Web Scientific Event in...  COVID-19
# 1  BACKGROUND: The Coronavirus disease 2019 (COVI...  COVID-19
# 2                                                     COVID-19
# 3  To provide a comprehensive and systematic anal...  COVID-19
# 4  An unprecedented worldwide spread of the SARS-...  COVID-19

# %%
Pub_CV['Content'] = Pub_CV['TI'] + Pub_CV['AB']
CV_1 = Pub_CV[['Content' , 'Type']]
CV_1.head()
# Out:
#                                              Content      Type
# 0  Update in COVID-19 in the intensive care unit ...  COVID-19
# 1  Rapid SARS-CoV-2 antigen detection assay in co...  COVID-19
# 2  Evaluation of the Panbio COVID-19 Rapid Antige...  COVID-19
# 3  A systematic review and meta-analysis of child...  COVID-19
# 4  COVID-19: Advances in diagnostic tools, treatm...  COVID-19

# %%
e1 = CV_1.head(2000)

# %% [markdown]
# # Cancer

# %%
ClassType= 'cancer'
Inputfile = 'pubmed-cancer-set_10000.txt'

# %%
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    Lines = file_input.readlines()
    #print (Lines)
cnt = 0
LineIndex = 0
PMID_LineIndex = []
for OneLine in Lines:
    LineIndex = LineIndex + 1
    if (OneLine.startswith('PMID-')):
        cnt = cnt +1
        PMID_LineIndex.append(LineIndex)
PMID_LineIndex.append(LineIndex)
#print(cnt)    
#print(PMID_LineIndex)


PUMID_List = []
TI_List = []
AB_List = []
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    for i in range(0,cnt):
        StartLineIndex = PMID_LineIndex[i]
        EndLineIndex = PMID_LineIndex[i+1]
        OnePUMID = []
        for j in range(StartLineIndex,EndLineIndex):
            OneLine = file_input.readline()
            #OneLine = OneLine.strip()
            #print(OneLine)
            OnePUMID.append(OneLine)
        #print(len(OnePUMID))
        #print(OnePUMID)
        #for k in range(len(OnePUMID)):
        OnePubMed_LineCnt = len(OnePUMID)
        #print(OnePubMed_LineCnt)
        OneTI_Info = []
        OneAB_Info = []
        k=0
        while (k < OnePubMed_LineCnt):
            #print(str(k)+'=>'+OnePUMID[k])
            if (OnePUMID[k].startswith('PMID-')):
                OnePUMID_Info = OnePUMID[k].split('- ')
                #print(str(k)+' PMID:'+OnePUMID_Info[1])
            #if (OnePUMID[k].startswith('TI  -')): # 
            if (OnePUMID[k].startswith('TI  -') or OnePUMID[k].startswith('Ti  -')):
                OneTI_Info = OnePUMID[k].split('- ')
                OneTI_Info[1] = OneTI_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneTI_Info[1] = OneTI_Info[1]+' '+Temp[1].strip()
                    k += 1
                #print(str(k)+' TI:'+OneTI_Info[1])
            if (OnePUMID[k].startswith('AB  -')):
                OneAB_Info = OnePUMID[k].split('- ')
                OneAB_Info[1] = OneAB_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneAB_Info[1] = OneAB_Info[1]+' '+Temp[1].strip()
                    k += 1
               # print(str(k)+' AB:'+OneAB_Info[1])
            k += 1
        PUMID_List.append(OnePUMID_Info[1].strip())
        TI_List.append(OneTI_Info[1].strip())
        if (len(OneAB_Info) == 2):
            AB_List.append(OneAB_Info[1].strip())
        else:
            AB_List.append('')
            print(OnePUMID_Info[1].strip()+"No Abstract")
        #AB_List.append(OneAB_Info[1].strip())
# Out:
# 26891021No Abstract
# 33173229No Abstract
# 32527812No Abstract
# 28215969No Abstract
# 22781673No Abstract
# 21383734No Abstract
# 24476996No Abstract
# 18292589No Abstract
# 12509774No Abstract
# 30814701No Abstract
# 29293229No Abstract
# 31444113No Abstract
# 20185704No Abstract
# 30538210No Abstract
# 25873737No Abstract
# 24283016No Abstract
# 30762975No Abstract
# 21682134No Abstract
# 15077361No Abstract
# 6358137No Abstract
# 19360048No Abstract
# 2392396No Abstract
# 17717165No Abstract
# 25223197No Abstract
# 21368346No Abstract
# 28443706No Abstract
# 28263382No Abstract
# 6898180No Abstract
# 34015788No Abstract
# 15657336No Abstract
# 16116730No Abstract
# 23072000No Abstract
# 6728392No Abstract
# 15769950No Abstract
# 6567449No Abstract
# 24339219No Abstract
# 24611191No Abstract
# 24824473No Abstract
# 25518070No Abstract
# 20233814No Abstract
# 19351914No Abstract
# 9168273No Abstract
# 16223832No Abstract
# 4881772No Abstract
# 13924428No Abstract
# ...

# %%
PubMed_Data = [[PUMID_List[i],TI_List[i],AB_List[i]] for i in range(cnt)]
Pub_Cancer = pd.DataFrame(PubMed_Data , columns = ['PUMID' , 'TI','AB'])
Pub_Cancer['Type'] = ClassType

Pub_Cancer.head()
# Out:
#       PUMID                                                 TI  \
# 0  28244479              Cancer and cure: A critical analysis.
# 1  29949179  Tumor microenvironment: recent advances in var...
# 2  26667886  Global Cancer Incidence and Mortality Rates an...
# 3  30713326  Recent Updates on the Relationship between Can...
# 4  31761807                                    What Is Cancer?
#
#                                                   AB    Type
# 0  Cancer is one of the most dreaded diseases of ...  cancer
# 1  This is a review regarding different types of ...  cancer
# 2  There are limited published data on recent can...  cancer
# 3  Autoimmune pancreatitis (AIP) is now considere...  cancer
# 4  This essay focuses on themes in Explaining Can...  cancer

# %%
Pub_Cancer['Content'] = Pub_Cancer['TI'] + Pub_Cancer['AB']
Cancer_1 = Pub_Cancer[['Content' , 'Type']]
Cancer_1.head()
# Out:
#                                              Content    Type
# 0  Cancer and cure: A critical analysis.Cancer is...  cancer
# 1  Tumor microenvironment: recent advances in var...  cancer
# 2  Global Cancer Incidence and Mortality Rates an...  cancer
# 3  Recent Updates on the Relationship between Can...  cancer
# 4  What Is Cancer?This essay focuses on themes in...  cancer

# %%
b1 = Cancer_1.head(2000)

# %% [markdown]
# # Genome

# %%
ClassType= 'genome'
Inputfile = 'pubmed-genome-set_10000.txt'

# %%
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    Lines = file_input.readlines()
    #print (Lines)
cnt = 0
LineIndex = 0
PMID_LineIndex = []
for OneLine in Lines:
    LineIndex = LineIndex + 1
    if (OneLine.startswith('PMID-')):
        cnt = cnt +1
        PMID_LineIndex.append(LineIndex)
PMID_LineIndex.append(LineIndex)
#print(cnt)    
#print(PMID_LineIndex)


PUMID_List = []
TI_List = []
AB_List = []
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    for i in range(0,cnt):
        StartLineIndex = PMID_LineIndex[i]
        EndLineIndex = PMID_LineIndex[i+1]
        OnePUMID = []
        for j in range(StartLineIndex,EndLineIndex):
            OneLine = file_input.readline()
            #OneLine = OneLine.strip()
            #print(OneLine)
            OnePUMID.append(OneLine)
        #print(len(OnePUMID))
        #print(OnePUMID)
        #for k in range(len(OnePUMID)):
        OnePubMed_LineCnt = len(OnePUMID)
        #print(OnePubMed_LineCnt)
        OneTI_Info = []
        OneAB_Info = []
        k=0
        while (k < OnePubMed_LineCnt):
            #print(str(k)+'=>'+OnePUMID[k])
            if (OnePUMID[k].startswith('PMID-')):
                OnePUMID_Info = OnePUMID[k].split('- ')
                #print(str(k)+' PMID:'+OnePUMID_Info[1])
            #if (OnePUMID[k].startswith('TI  -')): # 
            if (OnePUMID[k].startswith('TI  -') or OnePUMID[k].startswith('Ti  -')):
                OneTI_Info = OnePUMID[k].split('- ')
                OneTI_Info[1] = OneTI_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneTI_Info[1] = OneTI_Info[1]+' '+Temp[1].strip()
                    k += 1
                #print(str(k)+' TI:'+OneTI_Info[1])
            if (OnePUMID[k].startswith('AB  -')):
                OneAB_Info = OnePUMID[k].split('- ')
                OneAB_Info[1] = OneAB_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneAB_Info[1] = OneAB_Info[1]+' '+Temp[1].strip()
                    k += 1
               # print(str(k)+' AB:'+OneAB_Info[1])
            k += 1
        PUMID_List.append(OnePUMID_Info[1].strip())
        TI_List.append(OneTI_Info[1].strip())
        if (len(OneAB_Info) == 2):
            AB_List.append(OneAB_Info[1].strip())
        else:
            AB_List.append('')
            print(OnePUMID_Info[1].strip()+"No Abstract")
        #AB_List.append(OneAB_Info[1].strip())
        
       
#PUMID_List
#TI_List
# Out:
# 24108012No Abstract
# 21310998No Abstract
# 30824868No Abstract
# 15525218No Abstract
# 15955910No Abstract
# 29164758No Abstract
# 18327223No Abstract
# 26448084No Abstract
# 11961543No Abstract
# 24942153No Abstract
# 26163976No Abstract
# 22195527No Abstract
# 14993295No Abstract
# 19691844No Abstract
# 11854041No Abstract
# 17370570No Abstract
# 12239850No Abstract
# 11145428No Abstract
# 21324351No Abstract
# 17522639No Abstract
# 16670439No Abstract
# 11087172No Abstract
# 23857863No Abstract
# 32902773No Abstract
# 21536725No Abstract
# 18337796No Abstract
# 25637556No Abstract
# 16273050No Abstract
# 21996474No Abstract
# 27160922No Abstract
# 11549309No Abstract
# 16683016No Abstract
# 20513140No Abstract
# 21835310No Abstract
# 22314723No Abstract
# 12236059No Abstract
# 12634812No Abstract
# 34544148No Abstract
# 17658903No Abstract
# 30097718No Abstract
# 24196000No Abstract
# 12968190No Abstract
# 24915734No Abstract
# 29492778No Abstract
# 29575104No Abstract
# ...

# %%
PubMed_Data = [[PUMID_List[i],TI_List[i],AB_List[i]] for i in range(cnt)]
Pub_genome = pd.DataFrame(PubMed_Data , columns = ['PUMID' , 'TI','AB'])
Pub_genome['Type'] = ClassType

Pub_genome.head()
# Out:
#       PUMID                                                 TI  \
# 0  32034321              Pan-genomics in the human genome era.
# 1  28968633       Microbial genome analysis: the COG approach.
# 2  30485757  New Approaches for Genome Assembly and Scaffol...
# 3  25722247  Insights from 20 years of bacterial genome seq...
# 4  30465231             Whole genome engineering by synthesis.
#
#                                                   AB    Type
# 0  Since the early days of the genome era, the sc...  genome
# 1  For the past 20 years, the Clusters of Ortholo...  genome
# 2  Affordable, high-throughput DNA sequencing has...  genome
# 3  Since the first two complete bacterial genome ...  genome
# 4  Whole genome engineering is now feasible with ...  genome

# %%
Pub_genome['Content'] = Pub_genome['TI'] + Pub_genome['AB']
genome_1 = Pub_genome[['Content' , 'Type']]
genome_1.head()
# Out:
#                                              Content    Type
# 0  Pan-genomics in the human genome era.Since the...  genome
# 1  Microbial genome analysis: the COG approach.Fo...  genome
# 2  New Approaches for Genome Assembly and Scaffol...  genome
# 3  Insights from 20 years of bacterial genome seq...  genome
# 4  Whole genome engineering by synthesis.Whole ge...  genome

# %%
c1 = genome_1.head(2000)

# %% [markdown]
# # Virus

# %%
ClassType= 'virus'
Inputfile = 'pubmed-virus-set_10000.txt'

# %%
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    Lines = file_input.readlines()
    #print (Lines)
cnt = 0
LineIndex = 0
PMID_LineIndex = []
for OneLine in Lines:
    LineIndex = LineIndex + 1
    if (OneLine.startswith('PMID-')):
        cnt = cnt +1
        PMID_LineIndex.append(LineIndex)
PMID_LineIndex.append(LineIndex)
#print(cnt)    
#print(PMID_LineIndex)


PUMID_List = []
TI_List = []
AB_List = []
with open (Inputfile, 'r',encoding="utf-8") as file_input:
    for i in range(0,cnt):
        StartLineIndex = PMID_LineIndex[i]
        EndLineIndex = PMID_LineIndex[i+1]
        OnePUMID = []
        for j in range(StartLineIndex,EndLineIndex):
            OneLine = file_input.readline()
            #OneLine = OneLine.strip()
            #print(OneLine)
            OnePUMID.append(OneLine)
        #print(len(OnePUMID))
        #print(OnePUMID)
        #for k in range(len(OnePUMID)):
        OnePubMed_LineCnt = len(OnePUMID)
        #print(OnePubMed_LineCnt)
        OneTI_Info = []
        OneAB_Info = []
        k=0
        while (k < OnePubMed_LineCnt):
            #print(str(k)+'=>'+OnePUMID[k])
            if (OnePUMID[k].startswith('PMID-')):
                OnePUMID_Info = OnePUMID[k].split('- ')
                #print(str(k)+' PMID:'+OnePUMID_Info[1])
            #if (OnePUMID[k].startswith('TI  -')): # 
            if (OnePUMID[k].startswith('TI  -') or OnePUMID[k].startswith('Ti  -')):
                OneTI_Info = OnePUMID[k].split('- ')
                OneTI_Info[1] = OneTI_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneTI_Info[1] = OneTI_Info[1]+' '+Temp[1].strip()
                    k += 1
                #print(str(k)+' TI:'+OneTI_Info[1])
            if (OnePUMID[k].startswith('AB  -')):
                OneAB_Info = OnePUMID[k].split('- ')
                OneAB_Info[1] = OneAB_Info[1].strip()
                while (OnePUMID[k+1].startswith('   ')):
                    Temp = OnePUMID[k+1].split('    ')
                    #print(OnePUMID[k+1])
                    OneAB_Info[1] = OneAB_Info[1]+' '+Temp[1].strip()
                    k += 1
               # print(str(k)+' AB:'+OneAB_Info[1])
            k += 1
        PUMID_List.append(OnePUMID_Info[1].strip())
        TI_List.append(OneTI_Info[1].strip())
        if (len(OneAB_Info) == 2):
            AB_List.append(OneAB_Info[1].strip())
        else:
            AB_List.append('')
            print(OnePUMID_Info[1].strip()+"No Abstract")
        #AB_List.append(OneAB_Info[1].strip())
        
       
#PUMID_List
#TI_List
# Out:
# 28743434No Abstract
# 33328031No Abstract
# 17027678No Abstract
# 7772620No Abstract
# 9551597No Abstract
# 15053016No Abstract
# 21994789No Abstract
# 11050947No Abstract
# 29092671No Abstract
# 14675862No Abstract
# 28622998No Abstract
# 25766213No Abstract
# 23959999No Abstract
# 29406152No Abstract
# 25672290No Abstract
# 13970149No Abstract
# 31865667No Abstract
# 13774265No Abstract
# 13733735No Abstract
# 28087690No Abstract
# 13819251No Abstract
# 11212754No Abstract
# 24680706No Abstract
# 26535450No Abstract
# 13725646No Abstract
# 8634029No Abstract
# 22440967No Abstract
# 22135322No Abstract
# 14449377No Abstract
# 17455614No Abstract
# 22482706No Abstract
# 22883351No Abstract
# 28279325No Abstract
# 13745227No Abstract
# 13793362No Abstract
# 13764997No Abstract
# 13749013No Abstract
# 14467780No Abstract
# 12915096No Abstract
# 13876064No Abstract
# 13696321No Abstract
# 20375597No Abstract
# 13745540No Abstract
# 22440620No Abstract
# 13780066No Abstract
# ...

# %%
PubMed_Data = [[PUMID_List[i],TI_List[i],AB_List[i]] for i in range(cnt)]
Pub_virus = pd.DataFrame(PubMed_Data , columns = ['PUMID' , 'TI','AB'])
Pub_virus['Type'] = ClassType

# %%
Pub_virus.head()
# Out:
#       PUMID                                                 TI  \
# 0  27070380                 A Literature Review of Zika Virus.
# 1  30039318                               Virus classification
# 2  30081492  Mutation and Epistasis in Influenza Virus Evol...
# 3  28456056        Virus population dynamics during infection.
# 4  22440970  Virus disinfection mechanisms: the role of vir...
#
#                                                   AB   Type
# 0  Zika virus is a mosquitoborne flavivirus that ...  virus
# 1  High-throughput sequencing (HTS) and its use i...  virus
# 2  Influenza remains a persistent public health c...  virus
# 3  During RNA virus infection of a host, error-pr...  virus
# 4  Drinking waters are treated for enteric virus ...  virus

# %%
Pub_virus['Content'] = Pub_virus['TI'] + Pub_virus['AB']
virus_1 = Pub_virus[['Content' , 'Type']]
virus_1.head()
# Out:
#                                              Content   Type
# 0  A Literature Review of Zika Virus.Zika virus i...  virus
# 1  Virus classificationHigh-throughput sequencing...  virus
# 2  Mutation and Epistasis in Influenza Virus Evol...  virus
# 3  Virus population dynamics during infection.Dur...  virus
# 4  Virus disinfection mechanisms: the role of vir...  virus

# %%
d1 = virus_1.head(2000)

# %% [markdown]
# # Concat all

# %%
frames = [vacc_1 , CV_1 , Cancer_1 , genome_1 ,virus_1]
df_final = pd.concat(frames)

# %%
fs = [a1,b1,c1,d1,e1]
df_short = pd.concat(fs)

# %%
df_final.head()
# Out:
#                                              Content     Type
# 0  Addressing HPV vaccine myths: practical inform...  vaccine
# 1  Recent Advances in Vaccine Technologies.This b...  vaccine
# 2  Vaccine Hesitancy: Where We Are and Where We A...  vaccine
# 3  What are the factors that contribute to parent...  vaccine
# 4  Vaccine hesitancy and healthcare providers.Whi...  vaccine

# %%
df_short['Type'].value_counts()
# Out:
# genome      2000
# COVID-19    2000
# vaccine     2000
# cancer      2000
# virus       2000
# Name: Type, dtype: int64

# %%
df_final['Type'].value_counts()
# Out:
# virus       10000
# genome      10000
# vaccine     10000
# COVID-19    10000
# cancer      10000
# Name: Type, dtype: int64

# %%
df_short.to_csv('Pubmed_GVVCC_SHORT_710.csv')

# %% [markdown]
# # Text Engineering

# %%
ClassIDMap = {'genome': 1, 'virus':2, 'vaccine':3, 'cancer': 4 ,'COVID-19' :5 }
ClassIDMap
# Out:
# {'genome': 1, 'virus': 2, 'vaccine': 3, 'cancer': 4, 'COVID-19': 5}

# %%
def put_onlabel(k):
    return ClassIDMap[k]

# %%
df_final['label'] = df_final['Type'].apply(lambda x : put_onlabel(x))

# %%
df_final.head()
# Out:
#                                              Content     Type  label
# 0  Addressing HPV vaccine myths: practical inform...  vaccine      3
# 1  Recent Advances in Vaccine Technologies.This b...  vaccine      3
# 2  Vaccine Hesitancy: Where We Are and Where We A...  vaccine      3
# 3  What are the factors that contribute to parent...  vaccine      3
# 4  Vaccine hesitancy and healthcare providers.Whi...  vaccine      3

# %%
total_nulls = df_final[df_final.Content.str.strip() == ''].shape[0]
print("Empty documents:", total_nulls)
# Out:
# Empty documents: 0

# %%
df_final.shape
# Out:
# (50000, 3)

# %%
# !pip install nltk
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\girish pandey\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize  
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

# %%
import numpy as np

# %%
a = df_final.iloc[766]['Content']
a
# Out:
# "Assessing the operational costs of routine immunization activities at the sub-center level in Myanmar: What matters for increasing national immunization coverage?BACKGROUND: Myanmar's national immunization program was launched in 1978. Routine immunization is mainly provided at sub-center level with midwives assigned as main vaccinators. The vaccinators at the sub-centers have to obtain vaccines from their designated township health department's cold room for immunization services. This study aimed to calculate the operational costs of routine immunization at sub-centers in Myanmar. METHODS: A cross-sectional study was conducted among 160 sub-centers throughout the country. Face-to-face interviews were conducted with the main vaccinator at each sub-center using a pre-tested questionnaire. The study analyzed the operational costs per facility and the associations between sub-center characteristics and operational costs. RESULTS: In Myanmar, the average operational costs of routine im
# ...

# %%
p_stemmer = PorterStemmer()

# %%
def nltk_process(text):
    #Tokenization
    nltk_tokenList = word_tokenize(text)
    
    #Stemming
    nltk_stemedList = []
    for word in nltk_tokenList:
        nltk_stemedList.append(p_stemmer.stem(word))
    
    #Lemmatization
    wordnet_lemmatizer = WordNetLemmatizer()
    nltk_lemmaList = []
    for word in nltk_stemedList:
        nltk_lemmaList.append(wordnet_lemmatizer.lemmatize(word))
    
    #Filter stopword
    filtered_sentence = []  
    nltk_stop_words = set(stopwords.words("english"))
    for w in nltk_lemmaList:  
        if w not in nltk_stop_words:  
            filtered_sentence.append(w)
    #Removing Punctuation
    punctuations=['!' ,'@' , '#' , '$' ,'%' ,'^' ,'&' ,'*' ,'(' 
                  ,')' ,'-' ,'_' ,'+' ,'=','[' ,']' ,'{' ,'}' ,':' ,';' ,'"'
                  ,"'" ,'<' ,'>',',','.','?','/','|']
    for word in filtered_sentence:
        if word in punctuations:
            filtered_sentence.remove(word)
    print(" ")
    print("Remove stopword & Punctuation")
    filtered_sentence = ' '.join(filtered_sentence)
    return filtered_sentence

# %%
nltk_process(a)
# Out:
#
# Remove stopword & Punctuation
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\GIRISH
# [nltk_data]     PANDEY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
df_short['clean_text'] = df_short['Content'].apply(lambda x : nltk_process(x))
# Out:
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# Remove stopword & Punctuation
#
# ...

# %%
df_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content     10000 non-null  object
#  1   Type        10000 non-null  object
#  2   clean_text  10000 non-null  object
# dtypes: object(3)
# memory usage: 312.5+ KB

# %%
df_short = df_short.replace(r'^(\s?)+$' , np.nan , regex = True)

# %%
df_short = df_short.dropna().reset_index(drop = True)
df_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content     10000 non-null  object
#  1   Type        10000 non-null  object
#  2   clean_text  10000 non-null  object
# dtypes: object(3)
# memory usage: 234.5+ KB

# %%
ClassIDMap = {'genome': 1, 'virus':2, 'vaccine':3, 'cancer': 4 ,'COVID-19' :5 }
ClassIDMap

def put_onlabel(k):
    return ClassIDMap[k]

df_short['label'] = df_short['Type'].apply(lambda x : put_onlabel(x))

# %%
df_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content     10000 non-null  object
#  1   Type        10000 non-null  object
#  2   clean_text  10000 non-null  object
#  3   label       10000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
from sklearn.model_selection import train_test_split

train_corpus , test_corpus , train_label_nums , test_label_nums , train_label_names , test_label_names = train_test_split(np.array(df_short['clean_text']) 
                                                                                                                          , np.array(df_short['label']),
                                                                                                                          np.array(df_short['Type']),
                                                                                                                          test_size = 0.33 , random_state = 42
                                                                                                                        
                                                                                                                         )
train_corpus.shape , test_corpus.shape
# Out:
# ((6700,), (3300,))

# %%
from collections import Counter
trd = dict(Counter(train_label_names))
tsd = dict(Counter(test_label_names))

(pd.DataFrame([[key , trd[key] , tsd[key] ] for key in trd ] ,
             columns = ['Target Label' , 'Train Count' , 'Test Count'])
 .sort_values(by = ['Train Count' , 'Test Count'],ascending = False ))
# Out:
#   Target Label  Train Count  Test Count
# 3        virus         1361         639
# 2       cancer         1353         647
# 0     COVID-19         1340         660
# 1       genome         1326         674
# 4      vaccine         1320         680

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score

cv = CountVectorizer(binary = False , min_df = 0.0 , max_df = 1.0)
cv_train_features = cv.fit_transform(train_corpus)

# %%
cv_train_features.shape
# Out:
# (6700, 24751)

# %%
cv_test_features = cv.transform(test_corpus)

# %%
cv_test_features.shape
# Out:
# (3300, 24751)

# %% [markdown]
# # Naive_Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

mnb = MultinomialNB(alpha =1)
mnb.fit(cv_train_features , train_label_names)
mnb_bow_cv_scores = cross_val_score(mnb , cv_train_features , train_label_names , cv=5)
mnb_bow_cv_mean_score = np.mean(mnb_bow_cv_scores)
print('CV Accuracy (5-fold) : ' , mnb_bow_cv_scores)
print('Mean CV Accuracy : ' , mnb_bow_cv_mean_score)
mnb_bow_test_score = mnb.score(cv_test_features , test_label_names)
print('Test Accuracy :' , mnb_bow_test_score)
# Out:
# CV Accuracy (5-fold) :  [0.97686567 0.97985075 0.96641791 0.96791045 0.97537313]
# Mean CV Accuracy :  0.9732835820895522
# Test Accuracy : 0.9736363636363636

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(penalty = 'l2' , max_iter = 50 , C=1
                      ,random_state = 42)
lr.fit(cv_train_features , train_label_names)
lr_bow_cv_scores = cross_val_score(lr , cv_train_features , train_label_names , cv=5)
lr_bow_cv_mean_score = np.mean(lr_bow_cv_scores)
print('CV Accuracy (5-fold) : ' , lr_bow_cv_scores)
print('Mean CV Accuracy : ' , lr_bow_cv_mean_score)
lr_bow_test_score = lr.score(cv_test_features , test_label_names)
print('Test Accuracy :' , lr_bow_test_score)
# Out:
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # Linear SVC

# %%
from sklearn.svm import LinearSVC

svm = LinearSVC(penalty = 'l2' , C =1 , random_state = 42)
svm.fit(cv_train_features , train_label_names)
svm_bow_cv_scores = cross_val_score(svm , cv_train_features , train_label_names , cv=5)
svm_bow_cv_mean_score = np.mean(svm_bow_cv_scores)
print('CV Accuracy (5-fold) : ' , svm_bow_cv_scores)
print('Mean CV Accuracy : ' , svm_bow_cv_mean_score)
svm_bow_test_score = svm.score(cv_test_features , test_label_names)
print('Test Accuracy :' , svm_bow_test_score)
# Out:
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# CV Accuracy (5-fold) :  [0.97537313 0.97089552 0.97313433 0.98432836 0.98507463]
# Mean CV Accuracy :  0.9777611940298507
# Test Accuracy : 0.9818181818181818
# ...

# %% [markdown]
# # SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier

svm_sgd = SGDClassifier(penalty = 'l2' ,loss = 'hinge' , max_iter = 5 , random_state = 42)
svm_sgd.fit(cv_train_features , train_label_names)
svm_sgd_bow_cv_scores = cross_val_score(svm_sgd , cv_train_features , train_label_names , cv=5)
svm_sgd_bow_cv_mean_score = np.mean(svm_sgd_bow_cv_scores)
print('CV Accuracy (5-fold) : ' , svm_sgd_bow_cv_scores)
print('Mean CV Accuracy : ' , svm_sgd_bow_cv_mean_score)
svm_sgd_bow_test_score = svm_sgd.score(cv_test_features , test_label_names)
print('Test Accuracy :' , svm_sgd_bow_test_score)
# Out:
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# ...

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators = 10, random_state = 42)
rfc.fit(cv_train_features , train_label_names)
rfc_bow_cv_scores = cross_val_score(rfc , cv_train_features , train_label_names , cv=5)
rfc_bow_cv_mean_score = np.mean(rfc_bow_cv_scores)
print('CV Accuracy (5-fold) : ' , rfc_bow_cv_scores)
print('Mean CV Accuracy : ' , rfc_bow_cv_mean_score)
rfc_bow_test_score = rfc.score(cv_test_features , test_label_names)
print('Test Accuracy :' , rfc_bow_test_score)
# Out:
# CV Accuracy (5-fold) :  [0.95       0.93955224 0.94104478 0.95       0.95074627]
# Mean CV Accuracy :  0.9462686567164178
# Test Accuracy : 0.9496969696969697

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(n_estimators = 10, random_state = 42)
gbc.fit(cv_train_features , train_label_names)
gbc_bow_cv_scores = cross_val_score(gbc , cv_train_features , train_label_names , cv=5)
gbc_bow_cv_mean_score = np.mean(gbc_bow_cv_scores)
print('CV Accuracy (5-fold) : ' , gbc_bow_cv_scores)
print('Mean CV Accuracy : ' , gbc_bow_cv_mean_score)
gbc_bow_test_score = gbc.score(cv_test_features , test_label_names)
print('Test Accuracy :' , gbc_bow_test_score)
# Out:
# CV Accuracy (5-fold) :  [0.96268657 0.96641791 0.96940299 0.97238806 0.97761194]
# Mean CV Accuracy :  0.9697014925373135
# Test Accuracy : 0.9715151515151516

# %% [markdown]
# # TF IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tv = TfidfVectorizer(use_idf = True , min_df = 0.0 , max_df = 1.0)
tv_train_features = tv.fit_transform(train_corpus)
tv_test_features = tv.transform(test_corpus)

# %%
tv_train_features.shape , tv_test_features.shape
# Out:
# ((6700, 24751), (3300, 24751))

# %%
mnb = MultinomialNB(alpha =1)
mnb.fit(tv_train_features , train_label_names)
mnb_tfidf_cv_scores = cross_val_score(mnb , tv_train_features , train_label_names , cv=5)
mnb_tfidf_cv_mean_score = np.mean(mnb_tfidf_cv_scores)
print('CV Accuracy (5-fold) : ' , mnb_tfidf_cv_scores)
print('Mean CV Accuracy : ' , mnb_tfidf_cv_mean_score)
mnb_tfidf_test_score = mnb.score(cv_test_features , test_label_names)
print('Test Accuracy :' , mnb_tfidf_test_score)
# Out:
# CV Accuracy (5-fold) :  [0.96119403 0.9641791  0.95746269 0.95074627 0.95671642]
# Mean CV Accuracy :  0.9580597014925374
# Test Accuracy : 0.9627272727272728

# %%
lr = LogisticRegression(penalty = 'l2' , max_iter = 50 , C=1
                      ,random_state = 42)
lr.fit(tv_train_features , train_label_names)
lr_tfidf_cv_scores = cross_val_score(lr , tv_train_features , train_label_names , cv=5)
lr_tfidf_cv_mean_score = np.mean(lr_tfidf_cv_scores)
print('CV Accuracy (5-fold) : ' , lr_tfidf_cv_scores)
print('Mean CV Accuracy : ' , lr_tfidf_cv_mean_score)
lr_tfidf_test_score = lr.score(cv_test_features , test_label_names)
print('Test Accuracy :' , lr_tfidf_test_score)
# Out:
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
svm = LinearSVC(penalty = 'l2' , C =1 , random_state = 42)
svm.fit(tv_train_features , train_label_names)
svm_tfidf_cv_scores = cross_val_score(svm , tv_train_features , train_label_names , cv=5)
svm_tfidf_cv_mean_score = np.mean(svm_tfidf_cv_scores)
print('CV Accuracy (5-fold) : ' , svm_tfidf_cv_scores)
print('Mean CV Accuracy : ' , svm_tfidf_cv_mean_score)
svm_tfidf_test_score = svm.score(cv_test_features , test_label_names)
print('Test Accuracy :' , svm_tfidf_test_score)
# Out:
# CV Accuracy (5-fold) :  [0.98134328 0.98283582 0.97835821 0.98955224 0.9880597 ]
# Mean CV Accuracy :  0.9840298507462688
# Test Accuracy : 0.9818181818181818

# %%
svm_sgd = SGDClassifier(penalty = 'l2' ,loss = 'hinge' , max_iter = 5 , random_state = 42)
svm_sgd.fit(tv_train_features , train_label_names)
svm_sgd_tfidf_cv_scores = cross_val_score(svm_sgd , tv_train_features , train_label_names , cv=5)
svm_sgd_tfidf_cv_mean_score = np.mean(svm_sgd_tfidf_cv_scores)
print('CV Accuracy (5-fold) : ' , svm_sgd_tfidf_cv_scores)
print('Mean CV Accuracy : ' , svm_sgd_tfidf_cv_mean_score)
svm_sgd_tfidf_test_score = svm_sgd.score(cv_test_features , test_label_names)
print('Test Accuracy :' , svm_sgd_tfidf_test_score)
# Out:
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# C:\Users\GIRISH PANDEY\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# ...

# %%
rfc = RandomForestClassifier(n_estimators = 10, random_state = 42)
rfc.fit(tv_train_features , train_label_names)
rfc_tfidf_cv_scores = cross_val_score(rfc , tv_train_features , train_label_names , cv=5)
rfc_tfidf_cv_mean_score = np.mean(rfc_tfidf_cv_scores)
print('CV Accuracy (5-fold) : ' , rfc_tfidf_cv_scores)
print('Mean CV Accuracy : ' , rfc_tfidf_cv_mean_score)
rfc_tfidf_test_score = rfc.score(cv_test_features , test_label_names)
print('Test Accuracy :' , rfc_tfidf_test_score)
# Out:
# CV Accuracy (5-fold) :  [0.95149254 0.94402985 0.94925373 0.9380597  0.94402985]
# Mean CV Accuracy :  0.9453731343283582
# Test Accuracy : 0.9212121212121213

# %%
gbc = GradientBoostingClassifier(n_estimators = 10, random_state = 42)
gbc.fit(tv_train_features , train_label_names)
gbc_tfidf_cv_scores = cross_val_score(gbc , tv_train_features , train_label_names , cv=5)
gbc_tfidf_cv_mean_score = np.mean(gbc_tfidf_cv_scores)
print('CV Accuracy (5-fold) : ' , gbc_tfidf_cv_scores)
print('Mean CV Accuracy : ' , gbc_tfidf_cv_mean_score)
gbc_tfidf_test_score = gbc.score(cv_test_features , test_label_names)
print('Test Accuracy :' , gbc_tfidf_test_score)
# Out:
# CV Accuracy (5-fold) :  [0.97089552 0.96641791 0.96940299 0.97089552 0.98134328]
# Mean CV Accuracy :  0.9717910447761193
# Test Accuracy : 0.9475757575757576

# %%
df_2 = pd.DataFrame([['Naive Bayes' , mnb_bow_cv_mean_score , mnb_bow_test_score,
              mnb_tfidf_cv_mean_score , mnb_tfidf_test_score],
              ['Logistic Regression' , lr_bow_cv_mean_score , lr_bow_test_score,
              lr_tfidf_cv_mean_score , lr_tfidf_test_score],
              ['Linear SVM' , svm_bow_cv_mean_score , svm_bow_test_score,
              svm_tfidf_cv_mean_score , svm_tfidf_test_score],
              ['Linear svm_sgd (SGD)' , svm_sgd_bow_cv_mean_score , svm_sgd_bow_test_score,
              svm_sgd_tfidf_cv_mean_score , svm_sgd_tfidf_test_score],
              ['Random Forest' , rfc_bow_cv_mean_score , rfc_bow_test_score,
              rfc_tfidf_cv_mean_score , rfc_tfidf_test_score],
              ['Gradient Boosted Machines' , gbc_bow_cv_mean_score , gbc_bow_test_score,
              gbc_tfidf_cv_mean_score , gbc_tfidf_test_score]],
              columns = ['Model' , 'CV Score (TF)' ,'Test Score (TF)' ,
                        'CV Score (TF-IDF)' , 'Test Score (TF-IDF)']
             )

# %%
df_2
# Out:
#                        Model  CV Score (TF)  Test Score (TF)  \
# 0                Naive Bayes       0.973284         0.973636
# 1        Logistic Regression       0.980597         0.982121
# 2                 Linear SVM       0.977761         0.981818
# 3       Linear svm_sgd (SGD)       0.977910         0.982424
# 4              Random Forest       0.946269         0.949697
# 5  Gradient Boosted Machines       0.969701         0.971515
#
#    CV Score (TF-IDF)  Test Score (TF-IDF)
# 0           0.958060             0.962727
# 1           0.981493             0.972424
# 2           0.984030             0.981818
# 3           0.984627             0.982424
# 4           0.945373             0.921212
# 5           0.971791             0.947576
